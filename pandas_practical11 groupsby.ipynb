# %% [markdown]
# # pandas group by function

# %%
import pandas as pd

# %%
df2 = pd.read_csv("D:\\machine learning data sets\\student_results.csv")
df2
# Out:
#    Student ID  Class  Study hrs  Sleeping hrs  Social Media usage hrs  \
# 0        1001     10          2             9                       3
# 1        1002     10          6             8                       2
# 2        1003     10          3             8                       2
# 3        1004     11          0            10                       1
# 4        1005     11          4             7                       2
# 5        1006     11         10             7                       0
# 6        1007     12          4             6                       0
# 7        1008     12         10             6                       2
# 8        1009     12          2             8                       2
# 9        1010     12          6             9                       1
#
#    Mobile Games hrs  Percantege
# 0                 5          50
# 1                 0          80
# 2                 4          60
# 3                 5          45
# ...

# %%
gr1 = df2.groupby(by = 'Sleeping hrs')
print(gr1)

# %%
gr1.groups
# Out:
# {6: [6, 7], 7: [4, 5], 8: [1, 2, 8], 9: [0, 9], 10: [3]}

# %%
gr1.sum()
# Out:
#               Student ID  Class  Study hrs  Social Media usage hrs  \
# Sleeping hrs
# 6                   2015     24         14                       2
# 7                   2011     22         14                       2
# 8                   3014     32         11                       6
# 9                   2011     22          8                       4
# 10                  1004     11          0                       1
#
#               Mobile Games hrs  Percantege
# Sleeping hrs
# 6                            0         170
# 7                            0         171
# 8                            8         200
# 9                            5         135
# 10                           5          45

# %%
gr1.describe()
# Out:
#              Student ID                                                  \
#                   count         mean       std     min      25%     50%
# Sleeping hrs
# 6                   2.0  1007.500000  0.707107  1007.0  1007.25  1007.5
# 7                   2.0  1005.500000  0.707107  1005.0  1005.25  1005.5
# 8                   3.0  1004.666667  3.785939  1002.0  1002.50  1003.0
# 9                   2.0  1005.500000  6.363961  1001.0  1003.25  1005.5
# 10                  1.0  1004.000000       NaN  1004.0  1004.00  1004.0
#
#                               Class             ... Mobile Games hrs       \
#                   75%     max count       mean  ...              75%  max
# Sleeping hrs                                    ...
# 6             1007.75  1008.0   2.0  12.000000  ...             0.00  0.0
# 7             1005.75  1006.0   2.0  11.000000  ...             0.00  0.0
# 8             1006.00  1009.0   3.0  10.666667  ...             4.00  4.0
# ...

# %%
gr1.agg(['sum','min','max'])
# Out:
#              Student ID             Class         Study hrs          \
#                     sum   min   max   sum min max       sum min max
# Sleeping hrs
# 6                  2015  1007  1008    24  12  12        14   4  10
# 7                  2011  1005  1006    22  11  11        14   4  10
# 8                  3014  1002  1009    32  10  12        11   2   6
# 9                  2011  1001  1010    22  10  12         8   2   6
# 10                 1004  1004  1004    11  11  11         0   0   0
#
#              Social Media usage hrs         Mobile Games hrs          \
#                                 sum min max              sum min max
# Sleeping hrs
# 6                                 2   0   2                0   0   0
# 7                                 2   0   2                0   0   0
# 8                                 6   2   2                8   0   4
# 9                                 4   1   3                5   0   5
# ...

# %%
df2.groupby(['Class','Sleeping hrs']).groups
# Out:
# {(10, 8): [1, 2], (10, 9): [0], (11, 7): [4, 5], (11, 10): [3], (12, 6): [6, 7], (12, 8): [8], (12, 9): [9]}
